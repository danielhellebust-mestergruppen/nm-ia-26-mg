# %%
import json

with open("../datasets/detection_dataset/coco_dataset/annotations.json", "r") as f:
    data = json.load(f)

len(data)
# Out:
# 3

# %%
annotations = data.get("annotations")
len(annotations)
# Out:
# 22731

# %%
annotations[:50]
# Out:
# [{'id': 1,
#   'image_id': 1,
#   'category_id': 206,
#   'bbox': [141, 49, 169, 152],
#   'area': 25688,
#   'iscrowd': 0},
#  {'id': 2,
#   'image_id': 1,
#   'category_id': 206,
#   'bbox': [252, 49, 141, 146],
#   'area': 20586,
#   'iscrowd': 0},
#  {'id': 3,
#   'image_id': 1,
#   'category_id': 142,
#   'bbox': [374, 58, 140, 128],
#   'area': 17920,
#   'iscrowd': 0},
#  {'id': 4,
#   'image_id': 1,
#   'category_id': 222,
#   'bbox': [586, 65, 106, 114],
#   'area': 12084,
#   'iscrowd': 0},
#  {'id': 5,
#   'image_id': 1,
#   'category_id': 222,
#   'bbox': [671, 38, 128, 142],
#   'area': 18176,
#   'iscrowd': 0},
#  {'id': 6,
#   'image_id': 1,
#   'category_id': 325,
#   'bbox': [781, 20, 100, 160],
#   'area': 16000,
#   'iscrowd': 0},
#  {'id': 7,
#   'image_id': 1,
#   'category_id': 325,
#   'bbox': [865, 17, 100, 157],
#   'area': 15700,
#   'iscrowd': 0},
#  {'id': 8,
#   'image_id': 1,
#   'category_id': 182,
#   'bbox': [951, 11, 99, 164],
#   'area': 16236,
# ...

# %%
import pandas as pd

df = pd.DataFrame(annotations)
df
# Out:
#           id  image_id  category_id                  bbox     area  iscrowd
# 0          1         1          206   [141, 49, 169, 152]  25688.0        0
# 1          2         1          206   [252, 49, 141, 146]  20586.0        0
# 2          3         1          142   [374, 58, 140, 128]  17920.0        0
# 3          4         1          222   [586, 65, 106, 114]  12084.0        0
# 4          5         1          222   [671, 38, 128, 142]  18176.0        0
# ...      ...       ...          ...                   ...      ...      ...
# 22726  34358       382          132  [873, 1297, 102, 64]   6528.0        0
# 22727  34359       382           84  [514, 1183, 212, 87]  18444.0        0
# 22728  34360       382           84  [513, 1098, 214, 87]  18618.0        0
# 22729  34361       382           38  [149, 1131, 75, 123]   9225.0        0
# 22730  34362       382           38  [264, 1134, 76, 123]   9348.0        0
#
# [22731 rows x 6 columns]

# %%
images = data.get("images")
images[:5]
# Out:
# [{'id': 1, 'file_name': 'img_00001.jpg', 'width': 2000, 'height': 1500},
#  {'id': 2, 'file_name': 'img_00002.jpg', 'width': 2016, 'height': 1512},
#  {'id': 4, 'file_name': 'img_00004.jpg', 'width': 3200, 'height': 1440},
#  {'id': 5, 'file_name': 'img_00005.jpg', 'width': 4032, 'height': 3024},
#  {'id': 6, 'file_name': 'img_00006.jpg', 'width': 2728, 'height': 2070}]
